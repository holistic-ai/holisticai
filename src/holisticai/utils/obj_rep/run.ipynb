# %%
from holisticai.utils.obj_rep.object_repr import generate_html_for_generic_object

generic_object = {
    "dtype": "DatasetDict",
    "attributes": {},
    "metadata": {},
    "nested_objects": [
        {
            "dtype": "Dataset",
            "name": "train",
            "attributes": {"Number of Rows": 2480, "Features": ["x", "y", "group_a", "group_b"]},
            "metadata": "protected_attribute: race, group_a: white, group_h: no-white",
        },
        {
            "dtype": "Dataset",
            "name": "test",
            "attributes": {"Number of Rows": 2480, "Features": ["x", "y", "group_a", "group_b"]},
            "metadata": "race: {'group_a': 'white', 'group_b': 'no-white'}",
            "nested_objects": [],
        },
    ],
}

# Generate HTML representation for the generic object
html_output_generic_object = generate_html_for_generic_object(generic_object, feature_columns=5)

# %%
from IPython.core.display import HTML
HTML(html_output_generic_object)
# Out:
#     <style>
#         .generic-object-container {
#     padding: 1px;
#     margin: 1px;
# }
# .generic-object-content {
#     background-color: #fff;
#     border: 1px solid #ddd;
#     border-radius: 5px;
#     padding: 0px;
#     margin: 10px;
#     text-align: left;
#     font-family: Arial, sans-serif;
#     font-size: 11px;
#     color: #333;
#     display: inline-block;
#     box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.1);
# }
# .generic-object-header {
#     background-color: #e0e0e0;
#     color: #000;
#     font-size: 12px;
#     padding: 10px 150px 10px 20px;
#     margin: 0px;
#     text-align: left;
#     border-bottom: 1px solid #ccc;
#     border-radius: 5px 5px 0 0;
#     font-weight: bold;
# }
# .generic-object-body {
#     padding: 5px 10px 5px 10px;
# }
# .attribute-list {
#     margin: 2px 0;
#     padding: 2px;
# }
#     </style>
#     <div class="generic-object-container">
#         <div class="generic-object-content">
#             <div class="generic-object-header">DATASETDICT</div>
#             <div class="generic-object-body">
#
#
#     <style>
#         .generic-object-container {
#     padding: 1px;
#     margin: 1px;
# }
# .generic-object-content {
#     background-color: #fff;
#     border: 1px solid #ddd;
#     border-radius: 5px;
#     padding: 0px;
#     margin: 10px;
#     text-align: left;
#     font-family: Arial, sans-serif;
#     font-size: 11px;
#     color: #333;
#     display: inline-block;
#     box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.1);
# }
# .generic-object-header {
#     background-color: #e0e0e0;
#     color: #000;
#     font-size: 12px;
#     padding: 10px 150px 10px 20px;
#     margin: 0px;
#     text-align: left;
#     border-bottom: 1px solid #ccc;
#     border-radius: 5px 5px 0 0;
#     font-weight: bold;
# }
# .generic-object-body {
#     padding: 5px 10px 5px 10px;
# }
# .attribute-list {
#     margin: 2px 0;
#     padding: 2px;
# }
#     </style>
#     <div class="generic-object-container">
#         <div class="generic-object-content">
#             <div class="generic-object-header">train : DATASET</div>
#             <div class="generic-object-body">
#                 <div class="attribute-list">- Number of Rows: 2480</div><div class="attribute-list">- Features: x, y, group_a, group_b</div><div class="attribute-list">- Metadata: protected_attribute: race, group_a: white, group_h: no-white</div>
#
#             </div>
#         </div>
#     </div>
#
#     <style>
#         .generic-object-container {
#     padding: 1px;
#     margin: 1px;
# }
# .generic-object-content {
#     background-color: #fff;
#     border: 1px solid #ddd;
#     border-radius: 5px;
#     padding: 0px;
#     margin: 10px;
#     text-align: left;
#     font-family: Arial, sans-serif;
#     font-size: 11px;
#     color: #333;
#     display: inline-block;
#     box-shadow: 1px 1px 3px rgba(0, 0, 0, 0.1);
# }
# .generic-object-header {
#     background-color: #e0e0e0;
#     color: #000;
#     font-size: 12px;
#     padding: 10px 150px 10px 20px;
#     margin: 0px;
#     text-align: left;
#     border-bottom: 1px solid #ccc;
#     border-radius: 5px 5px 0 0;
#     font-weight: bold;
# }
# .generic-object-body {
#     padding: 5px 10px 5px 10px;
# }
# .attribute-list {
#     margin: 2px 0;
#     padding: 2px;
# }
#     </style>
#     <div class="generic-object-container">
#         <div class="generic-object-content">
#             <div class="generic-object-header">test : DATASET</div>
#             <div class="generic-object-body">
#                 <div class="attribute-list">- Number of Rows: 2480</div><div class="attribute-list">- Features: x, y, group_a, group_b</div><div class="attribute-list">- Metadata: race: {'group_a': 'white', 'group_b': 'no-white'}</div>
#
#             </div>
#         </div>
#     </div>
#
#             </div>
#         </div>
#     </div>
