# %% [markdown]
# # Explainability Metrics for Regression

# %%
import sys, os
base_path = os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))
sys.path.insert(0, base_path)

# %%
from holisticai.datasets import load_us_crime
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from holisticai.explainability import Explainer
from holisticai.efficacy.metrics import regression_efficacy_metrics

# %% [markdown]
# ## Data Preprocessing

# %%
dataset = load_us_crime(return_X_y=False, as_frame=True)
df = pd.concat([dataset["data"], dataset["target"]], axis=1)
df.head()
# Out:
#    state  county  community        communityname  fold  population  \
# 0    8.0     NaN        NaN         Lakewoodcity   1.0        0.19
# 1   53.0     NaN        NaN          Tukwilacity   1.0        0.00
# 2   24.0     NaN        NaN         Aberdeentown   1.0        0.00
# 3   34.0     5.0    81440.0  Willingborotownship   1.0        0.04
# 4   42.0    95.0     6096.0    Bethlehemtownship   1.0        0.01
#
#    householdsize  racepctblack  racePctWhite  racePctAsian  ...  LandArea  \
# 0           0.33          0.02          0.90          0.12  ...      0.12
# 1           0.16          0.12          0.74          0.45  ...      0.02
# 2           0.42          0.49          0.56          0.17  ...      0.01
# 3           0.77          1.00          0.08          0.12  ...      0.02
# 4           0.55          0.02          0.95          0.09  ...      0.04
#
#    PopDens  PctUsePubTrans  PolicCars  PolicOperBudg  LemasPctPolicOnPatr  \
# 0     0.26            0.20       0.06           0.04                  0.9
# 1     0.12            0.45        NaN            NaN                  NaN
# 2     0.21            0.02        NaN            NaN                  NaN
# 3     0.39            0.28        NaN            NaN                  NaN
# 4     0.09            0.02        NaN            NaN                  NaN
#
#    LemasGangUnitDeploy  LemasPctOfficDrugUn  PolicBudgPerPop  \
# 0                  0.5                 0.32             0.14
# 1                  NaN                 0.00              NaN
# 2                  NaN                 0.00              NaN
# 3                  NaN                 0.00              NaN
# 4                  NaN                 0.00              NaN
#
#    ViolentCrimesPerPop
# 0                 0.20
# 1                 0.67
# 2                 0.43
# 3                 0.12
# 4                 0.03
#
# [5 rows x 128 columns]

# %%
def preprocess_us_crime_dataset(df, protected_feature):
  """Performs the pre-processing step of the data."""
  # Remove NaN elements from dataframe
  df_ = df.copy()
  df_clean = df_.iloc[:,[i for i,n in enumerate(df_.isna().sum(axis=0).T.values) if n<1000]]
  df_clean = df_clean.dropna()
  # Get the protected attribute vectors
  group_a = df_clean[protected_feature].apply(lambda x: x>0.5)
  group_b =  1-group_a
  group_b = group_b.astype('bool')
  # Remove unnecessary columns
  cols = [c for c in df_clean.columns if (not c.startswith('race')) and (not c.startswith('age'))]
  df_clean = df_clean[cols].iloc[:,3:]
  return df_clean, group_a, group_b

# %%
df_clean, group_a, group_b = preprocess_us_crime_dataset(df, 'racePctWhite')
X = df_clean.iloc[:,:-1]
y = df_clean.iloc[:,-1]

# %%
from holisticai.bias.plots import correlation_matrix_plot

correlation_matrix_plot(X, target_feature='population', size = (12,7))
# Out:
# <Axes: >

# %% [markdown]
# ## Model Training

# %%
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np
seed = np.random.seed(42) # set seed for reproducibility
# simple preprocessing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed) # train test split


model = GradientBoostingRegressor() # instantiate model
#model = LinearRegression()
model.fit(X_train, y_train) # fit model

y_pred = model.predict(X_test) # compute predictions

# compute efficacy metrics
regression_efficacy_metrics(y_test, y_pred)
# Out:
#                   Value  Reference
# Metric
# RMSE       1.396764e-01          0
# MAE        9.038879e-02          0
# MAPE       1.185104e+12          0
# Max Error  7.651164e-01          0
# SMAPE      2.367336e-01          0

# %% [markdown]
# # Global Explainability Metrics (based on Permutation Feature Importance)

# %%
# permutation feature importance
explainer = Explainer(based_on='feature_importance',
                      strategy_type='permutation',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
explainer.metrics()
# Out:
#                         Value Reference
# Metric
# Explainability Ease  0.565217         1
# Fourth Fifths        0.641304         0
# Position Parity      0.042786         1
# Rank Alignment       0.444978         1
# Region Similarity    0.854376         1
# Spread Divergence    0.310633         -
# Spread Ratio         0.931303         0

# %%
explainer.bar_plot(max_display=10)

# %%
_,ax = plt.subplots(figsize=(15,3))
explainer.partial_dependence_plot(last=3, ax=ax)

# %% [markdown]
# Conditional Feature Importance Metrics

# %%
explainer.metrics()
# Out:
#                         Value Reference
# Metric
# Explainability Ease  0.565217         1
# Fourth Fifths        0.641304         0
# Position Parity      0.042786         1
# Rank Alignment       0.444978         1
# Region Similarity    0.854376         1
# Spread Divergence    0.310633         -
# Spread Ratio         0.931303         0

# %%
# How change the feature importance for each quantil with respect to the feature importance of the whole model?
explainer.contrast_visualization(show_connections=False)

# %%
explainer.feature_importance_table(sorted_by='Global', top_n=5)
# Out:
# <style type="text/css">
# #T_2d478_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 84.9%, transparent 84.9%);
# }
# #T_2d478_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 5.9%, transparent 5.9%);
# }
# #T_2d478_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 53.0%, transparent 53.0%);
# }
# #T_2d478_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
# }
# #T_2d478_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 92.7%, transparent 92.7%);
# }
# #T_2d478_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 61.1%, transparent 61.1%);
# }
# #T_2d478_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 7.6%, transparent 7.6%);
# }
# #T_2d478_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 50.2%, transparent 50.2%);
# }
# #T_2d478_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 73.6%, transparent 73.6%);
# }
# #T_2d478_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 60.4%, transparent 60.4%);
# }
# #T_2d478_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 20.6%, transparent 20.6%);
# }
# #T_2d478_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 70.2%, transparent 70.2%);
# }
# #T_2d478_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 39.9%, transparent 39.9%);
# }
# #T_2d478_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 21.3%, transparent 21.3%);
# }
# #T_2d478_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 7.8%, transparent 7.8%);
# }
# #T_2d478_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 9.0%, transparent 9.0%);
# }
# #T_2d478_row3_col1, #T_2d478_row3_col2, #T_2d478_row3_col3, #T_2d478_row4_col1, #T_2d478_row4_col2, #T_2d478_row4_col4 {
#   width: 10em;
# }
# #T_2d478_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 0.1%, transparent 0.1%);
# }
# #T_2d478_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 8.9%, transparent 8.9%);
# }
# #T_2d478_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_2d478">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2d478_level0_col0" class="col_heading level0 col0" >Global Importance</th>
#       <th id="T_2d478_level0_col1" class="col_heading level0 col1" >[Q0-Q1] Importance</th>
#       <th id="T_2d478_level0_col2" class="col_heading level0 col2" >[Q1-Q2] Importance</th>
#       <th id="T_2d478_level0_col3" class="col_heading level0 col3" >[Q2-Q3] Importance</th>
#       <th id="T_2d478_level0_col4" class="col_heading level0 col4" >[Q3-Q4] Importance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2d478_level0_row0" class="row_heading level0 row0" >PctIlleg</th>
#       <td id="T_2d478_row0_col0" class="data row0 col0" >0.106979</td>
#       <td id="T_2d478_row0_col1" class="data row0 col1" >0.007455</td>
#       <td id="T_2d478_row0_col2" class="data row0 col2" >0.066781</td>
#       <td id="T_2d478_row0_col3" class="data row0 col3" >0.126036</td>
#       <td id="T_2d478_row0_col4" class="data row0 col4" >0.116799</td>
#     </tr>
#     <tr>
#       <th id="T_2d478_level0_row1" class="row_heading level0 row1" >PctKids2Par</th>
#       <td id="T_2d478_row1_col0" class="data row1 col0" >0.077025</td>
#       <td id="T_2d478_row1_col1" class="data row1 col1" >0.009583</td>
#       <td id="T_2d478_row1_col2" class="data row1 col2" >0.063301</td>
#       <td id="T_2d478_row1_col3" class="data row1 col3" >0.092722</td>
#       <td id="T_2d478_row1_col4" class="data row1 col4" >0.076164</td>
#     </tr>
#     <tr>
#       <th id="T_2d478_level0_row2" class="row_heading level0 row2" >pctWInvInc</th>
#       <td id="T_2d478_row2_col0" class="data row2 col0" >0.025950</td>
#       <td id="T_2d478_row2_col1" class="data row2 col1" >0.088453</td>
#       <td id="T_2d478_row2_col2" class="data row2 col2" >0.050305</td>
#       <td id="T_2d478_row2_col3" class="data row2 col3" >0.026890</td>
#       <td id="T_2d478_row2_col4" class="data row2 col4" >0.009787</td>
#     </tr>
#     <tr>
#       <th id="T_2d478_level0_row3" class="row_heading level0 row3" >medIncome</th>
#       <td id="T_2d478_row3_col0" class="data row3 col0" >0.011319</td>
#       <td id="T_2d478_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_2d478_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_2d478_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_2d478_row3_col4" class="data row3 col4" >0.000077</td>
#     </tr>
#     <tr>
#       <th id="T_2d478_level0_row4" class="row_heading level0 row4" >numbUrban</th>
#       <td id="T_2d478_row4_col0" class="data row4 col0" >0.011216</td>
#       <td id="T_2d478_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_2d478_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_2d478_row4_col3" class="data row4 col3" >0.000032</td>
#       <td id="T_2d478_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Global Explainability metrics (based on Surrogate Model)

# %%
# surrogate feature importance
explainer = Explainer(based_on='feature_importance',
                      strategy_type='surrogate',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
explainer.metrics()
# Out:
#                         Value Reference
# Metric
# Explainability Ease  0.978261         1
# Fourth Fifths        0.010870         0
# Spread Divergence    3.463653         -
# Spread Ratio         0.234008         0
# Surrogacy Efficacy   0.129917         0

# %%
explainer.bar_plot(max_display=6)

# %%
_,ax = plt.subplots(figsize=(15,5))
explainer.partial_dependence_plot(last=6, ax=ax, kind='both')

# %%
explainer.feature_importance_table(sorted_by='Global', top_n=10)
# Out:
# <style type="text/css">
# #T_67d3b_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
# }
# #T_67d3b_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 18.4%, transparent 18.4%);
# }
# #T_67d3b_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 11.3%, transparent 11.3%);
# }
# #T_67d3b_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 5.5%, transparent 5.5%);
# }
# #T_67d3b_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 3.6%, transparent 3.6%);
# }
# #T_67d3b_row5_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 3.5%, transparent 3.5%);
# }
# #T_67d3b_row6_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 1.0%, transparent 1.0%);
# }
# #T_67d3b_row7_col0, #T_67d3b_row8_col0, #T_67d3b_row9_col0 {
#   width: 10em;
# }
# </style>
# <table id="T_67d3b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67d3b_level0_col0" class="col_heading level0 col0" >Global Importance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Variable</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67d3b_level0_row0" class="row_heading level0 row0" >PctIlleg</th>
#       <td id="T_67d3b_row0_col0" class="data row0 col0" >0.697821</td>
#     </tr>
#     <tr>
#       <th id="T_67d3b_level0_row1" class="row_heading level0 row1" >PctFam2Par</th>
#       <td id="T_67d3b_row1_col0" class="data row1 col0" >0.128331</td>
#     </tr>
#     <tr>
#       <th id="T_67d3b_level0_row2" class="row_heading level0 row2" >PctKids2Par</th>
#       <td id="T_67d3b_row2_col0" class="data row2 col0" >0.078922</td>
#     </tr>
#     <tr>
#       <th id="T_67d3b_level0_row3" class="row_heading level0 row3" >NumIlleg</th>
#       <td id="T_67d3b_row3_col0" class="data row3 col0" >0.038126</td>
#     </tr>
#     <tr>
#       <th id="T_67d3b_level0_row4" class="row_heading level0 row4" >PctLargHouseFam</th>
#       <td id="T_67d3b_row4_col0" class="data row4 col0" >0.025040</td>
#     </tr>
#     <tr>
#       <th id="T_67d3b_level0_row5" class="row_heading level0 row5" >PctPersDenseHous</th>
#       <td id="T_67d3b_row5_col0" class="data row5 col0" >0.024772</td>
#     </tr>
#     <tr>
#       <th id="T_67d3b_level0_row6" class="row_heading level0 row6" >FemalePctDiv</th>
#       <td id="T_67d3b_row6_col0" class="data row6 col0" >0.006988</td>
#     </tr>
#     <tr>
#       <th id="T_67d3b_level0_row7" class="row_heading level0 row7" >PctHousLess3BR</th>
#       <td id="T_67d3b_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_67d3b_level0_row8" class="row_heading level0 row8" >MedYrHousBuilt</th>
#       <td id="T_67d3b_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_67d3b_level0_row9" class="row_heading level0 row9" >PctVacMore6Mos</th>
#       <td id="T_67d3b_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
_,ax = plt.subplots(figsize=(15,3))
_ = explainer.tree_visualization('sklearn', fontsize=7, ax=ax)

# %%
#!pip install --upgrade pillow

# %%
explainer.tree_visualization('pydotplus')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1896x497>

# %%
vis = explainer.tree_visualization('dtreeviz', scale=2)
vis

# %% [markdown]
# # Local Explainability Metrics (based on Lime)

# %%
# lime feature importance
lime_explainer = Explainer(based_on='feature_importance',
                      strategy_type='lime',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
lime_explainer.metrics()
# Out:
#                       Value  Referemce
# Metric
# Data Stability     0.010377          0
# Feature Stability  0.002318          0

# %%
lime_explainer.metrics(detailed=True)
# Out:
#                               Value  Referemce
# Metric
# Data Stability             0.010377          0
# Data Stability [Q0-Q1]     0.005274          0
# Data Stability [Q1-Q2]     0.006159          0
# Data Stability [Q2-Q3]     0.009103          0
# Data Stability [Q3-Q4]     0.012926          0
# Feature Stability          0.002318          0
# Feature Stability [Q0-Q1]  0.003194          0
# Feature Stability [Q1-Q2]  0.003001          0
# Feature Stability [Q2-Q3]  0.004412          0
# Feature Stability [Q3-Q4]  0.007151          0

# %%
#explainer.feature_importance_table(sorted_by='Global', top_n=10)

# %%
lime_explainer.show_importance_stability()

# %%
lime_explainer.show_data_stability_boundaries(top_n=10, figsize=(15,5))

# %%
lime_explainer.show_features_stability_boundaries(figsize=(15,5))
