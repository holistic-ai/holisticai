# %%
import sys
sys.path.insert(0, '../../')

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from holisticai.explainability import Explainer
from holisticai.efficacy.metrics import regression_efficacy_metrics

# %%
dataset = load_diabetes() # load dataset

X = dataset.data # features
y = dataset.target # target 
feature_names = dataset.feature_names # feature names

X = pd.DataFrame(X, columns=feature_names) # convert to dataframe

# %%
X.hist(bins=10, figsize=(10, 10), color = 'mediumslateblue')
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'bp'}>, <Axes: title={'center': 's1'}>,
#         <Axes: title={'center': 's2'}>],
#        [<Axes: title={'center': 's3'}>, <Axes: title={'center': 's4'}>,
#         <Axes: title={'center': 's5'}>],
#        [<Axes: title={'center': 's6'}>, <Axes: >, <Axes: >]], dtype=object)

# %%
from holisticai.bias.plots import correlation_matrix_plot

correlation_matrix_plot(X, target_feature='age', size = (12,7))
# Out:
# <Axes: >

# %%
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np
seed = np.random.seed(42) # set seed for reproducibility
# simple preprocessing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed) # train test split


model = GradientBoostingRegressor() # instantiate model
model.fit(X_train, y_train) # fit model

y_pred = model.predict(X_test) # compute predictions

# compute efficacy metrics
regression_efficacy_metrics(y_test, y_pred)
# Out:
#                 Value  Reference
# Metric
# RMSE        53.952020          0
# MAE         44.638564          0
# MAPE         0.399881          0
# Max Error  131.736157          0
# SMAPE        0.164915          0

# %% [markdown]
# # Global Explainability Metrics (based on Permutation Feature Importance)

# %%
# permutation feature importance
permutation_explainer = Explainer(based_on='feature_importance',
                      strategy_type='permutation',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
permutation_explainer.metrics()
# Out:
#                                      Value Reference
# Fourth Fifths                     0.400000         0
# Importance Spread Divergence      0.460785         -
# Importance Spread Ratio           0.799884         0
# Global Overlap Score              0.306776         1
# Global Range Overlap Score        0.752946         1
# Global Similarity Score           0.840495         1
# Global Explainability Ease Score  0.750000         1

# %%
permutation_explainer.partial_dependence_plot()

# %%
permutation_explainer.metrics(detailed=True)
# Out:
#                                        Value Reference
# Fourth Fifths                       0.400000         0
# Importance Spread Divergence        0.460785         -
# Importance Spread Ratio             0.799884         0
# Global Overlap Score [Q0-Q1]        0.031111         1
# Global Overlap Score [Q1-Q2]        0.485794         1
# Global Overlap Score [Q2-Q3]        0.047897         1
# Global Overlap Score [Q3-Q4]        0.662302         1
# Global Range Overlap Score [Q0-Q1]  0.704048         1
# Global Range Overlap Score [Q1-Q2]  0.799484         1
# Global Range Overlap Score [Q2-Q3]  0.607817         1
# Global Range Overlap Score [Q3-Q4]  0.900437         1
# Global Similarity Score [Q0-Q1]     0.842255         1
# Global Similarity Score [Q1-Q2]     0.864839         1
# Global Similarity Score [Q2-Q3]     0.750187         1
# Global Similarity Score [Q3-Q4]     0.904698         1
# Global Explainability Ease Score    0.750000         1

# %%
# Contrast Whole Importance vs. Group Importance
# -> Order -> mean positions
# -> Range -> match range of position 
# -> Similarity -> compute similarity
# -> e.g. we can see that Q0-Q1 and Q2-Q3 strong changes in their position but their importance weights maintains a high similarity with the whole model.
# -> e.g. we can see that Q1-Q2 and Q3-Q4 small changes in their position and their importance weights maintains a high similarity with the whole model.
permutation_explainer.contrast_visualization(show_connections=False)
# TODO separate show connections sin a second matrix

# %%
permutation_explainer.bar_plot(max_display=10)

# %%
permutation_explainer.feature_importance_table(sorted_by='Global', top_n=5)
# Out:
# <style type="text/css">
# #T_46d09_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
# }
# #T_46d09_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 38.0%, transparent 38.0%);
# }
# #T_46d09_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 64.7%, transparent 64.7%);
# }
# #T_46d09_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 28.1%, transparent 28.1%);
# }
# #T_46d09_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 87.0%, transparent 87.0%);
# }
# #T_46d09_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 94.1%, transparent 94.1%);
# }
# #T_46d09_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 74.3%, transparent 74.3%);
# }
# #T_46d09_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 51.2%, transparent 51.2%);
# }
# #T_46d09_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 71.6%, transparent 71.6%);
# }
# #T_46d09_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 40.5%, transparent 40.5%);
# }
# #T_46d09_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 29.8%, transparent 29.8%);
# }
# #T_46d09_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.5%, transparent 22.5%);
# }
# #T_46d09_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 17.5%, transparent 17.5%);
# }
# #T_46d09_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 23.6%, transparent 23.6%);
# }
# #T_46d09_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 39.6%, transparent 39.6%);
# }
# #T_46d09_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 16.9%, transparent 16.9%);
# }
# #T_46d09_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 47.8%, transparent 47.8%);
# }
# #T_46d09_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 42.2%, transparent 42.2%);
# }
# #T_46d09_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 57.5%, transparent 57.5%);
# }
# #T_46d09_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 27.6%, transparent 27.6%);
# }
# #T_46d09_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 14.9%, transparent 14.9%);
# }
# #T_46d09_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.9%, transparent 22.9%);
# }
# #T_46d09_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 18.0%, transparent 18.0%);
# }
# #T_46d09_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 13.0%, transparent 13.0%);
# }
# #T_46d09_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 26.4%, transparent 26.4%);
# }
# </style>
# <table id="T_46d09">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_46d09_level0_col0" class="col_heading level0 col0" >Global Importance</th>
#       <th id="T_46d09_level0_col1" class="col_heading level0 col1" >[Q0-Q1] Importance</th>
#       <th id="T_46d09_level0_col2" class="col_heading level0 col2" >[Q1-Q2] Importance</th>
#       <th id="T_46d09_level0_col3" class="col_heading level0 col3" >[Q2-Q3] Importance</th>
#       <th id="T_46d09_level0_col4" class="col_heading level0 col4" >[Q3-Q4] Importance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_46d09_level0_row0" class="row_heading level0 row0" >bmi</th>
#       <td id="T_46d09_row0_col0" class="data row0 col0" >0.321886</td>
#       <td id="T_46d09_row0_col1" class="data row0 col1" >0.122267</td>
#       <td id="T_46d09_row0_col2" class="data row0 col2" >0.208239</td>
#       <td id="T_46d09_row0_col3" class="data row0 col3" >0.090481</td>
#       <td id="T_46d09_row0_col4" class="data row0 col4" >0.280007</td>
#     </tr>
#     <tr>
#       <th id="T_46d09_level0_row1" class="row_heading level0 row1" >s5</th>
#       <td id="T_46d09_row1_col0" class="data row1 col0" >0.302777</td>
#       <td id="T_46d09_row1_col1" class="data row1 col1" >0.239292</td>
#       <td id="T_46d09_row1_col2" class="data row1 col2" >0.164905</td>
#       <td id="T_46d09_row1_col3" class="data row1 col3" >0.230507</td>
#       <td id="T_46d09_row1_col4" class="data row1 col4" >0.130517</td>
#     </tr>
#     <tr>
#       <th id="T_46d09_level0_row2" class="row_heading level0 row2" >bp</th>
#       <td id="T_46d09_row2_col0" class="data row2 col0" >0.095825</td>
#       <td id="T_46d09_row2_col1" class="data row2 col1" >0.072358</td>
#       <td id="T_46d09_row2_col2" class="data row2 col2" >0.056336</td>
#       <td id="T_46d09_row2_col3" class="data row2 col3" >0.075909</td>
#       <td id="T_46d09_row2_col4" class="data row2 col4" >0.127500</td>
#     </tr>
#     <tr>
#       <th id="T_46d09_level0_row3" class="row_heading level0 row3" >age</th>
#       <td id="T_46d09_row3_col0" class="data row3 col0" >0.054271</td>
#       <td id="T_46d09_row3_col1" class="data row3 col1" >0.153966</td>
#       <td id="T_46d09_row3_col2" class="data row3 col2" >0.135719</td>
#       <td id="T_46d09_row3_col3" class="data row3 col3" >0.185101</td>
#       <td id="T_46d09_row3_col4" class="data row3 col4" >0.088731</td>
#     </tr>
#     <tr>
#       <th id="T_46d09_level0_row4" class="row_heading level0 row4" >s6</th>
#       <td id="T_46d09_row4_col0" class="data row4 col0" >0.047958</td>
#       <td id="T_46d09_row4_col1" class="data row4 col1" >0.073860</td>
#       <td id="T_46d09_row4_col2" class="data row4 col2" >0.058013</td>
#       <td id="T_46d09_row4_col3" class="data row4 col3" >0.041822</td>
#       <td id="T_46d09_row4_col4" class="data row4 col4" >0.085115</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Global Explainability metrics (based on Surrogate Model)

# %%
# surrogate feature importance
surrogate_explainer = Explainer(based_on='feature_importance',
                      strategy_type='surrogate',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
surrogate_explainer.metrics()
# Out:
#                                      Value Reference
# Fourth Fifths                     0.100000         0
# Importance Spread Divergence      1.533691         -
# Importance Spread Ratio           0.333927         0
# Global Explainability Ease Score  0.750000         1
# Surrogate Efficacy Regression     0.163279         0

# %%
_,ax=plt.subplots(figsize=(15,5))
surrogate_explainer.partial_dependence_plot(ax=ax, kind="both") # kind: [individual,average,both]

# %%
surrogate_explainer.bar_plot(max_display=5)

# %%
surrogate_explainer.feature_importance_table(sorted_by='Global', top_n=10)
# Out:
# <style type="text/css">
# #T_3b6dd_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
# }
# #T_3b6dd_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 40.8%, transparent 40.8%);
# }
# #T_3b6dd_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 3.3%, transparent 3.3%);
# }
# #T_3b6dd_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 2.4%, transparent 2.4%);
# }
# #T_3b6dd_row4_col0, #T_3b6dd_row5_col0, #T_3b6dd_row6_col0, #T_3b6dd_row7_col0, #T_3b6dd_row8_col0, #T_3b6dd_row9_col0 {
#   width: 10em;
# }
# </style>
# <table id="T_3b6dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b6dd_level0_col0" class="col_heading level0 col0" >Global Importance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Variable</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b6dd_level0_row0" class="row_heading level0 row0" >bmi</th>
#       <td id="T_3b6dd_row0_col0" class="data row0 col0" >0.682537</td>
#     </tr>
#     <tr>
#       <th id="T_3b6dd_level0_row1" class="row_heading level0 row1" >s5</th>
#       <td id="T_3b6dd_row1_col0" class="data row1 col0" >0.278768</td>
#     </tr>
#     <tr>
#       <th id="T_3b6dd_level0_row2" class="row_heading level0 row2" >s4</th>
#       <td id="T_3b6dd_row2_col0" class="data row2 col0" >0.022591</td>
#     </tr>
#     <tr>
#       <th id="T_3b6dd_level0_row3" class="row_heading level0 row3" >s2</th>
#       <td id="T_3b6dd_row3_col0" class="data row3 col0" >0.016105</td>
#     </tr>
#     <tr>
#       <th id="T_3b6dd_level0_row4" class="row_heading level0 row4" >age</th>
#       <td id="T_3b6dd_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3b6dd_level0_row5" class="row_heading level0 row5" >sex</th>
#       <td id="T_3b6dd_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3b6dd_level0_row6" class="row_heading level0 row6" >bp</th>
#       <td id="T_3b6dd_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3b6dd_level0_row7" class="row_heading level0 row7" >s1</th>
#       <td id="T_3b6dd_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3b6dd_level0_row8" class="row_heading level0 row8" >s3</th>
#       <td id="T_3b6dd_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3b6dd_level0_row9" class="row_heading level0 row9" >s6</th>
#       <td id="T_3b6dd_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
_,ax = plt.subplots(figsize=(15,3))
_ = surrogate_explainer.tree_visualization('sklearn', ax=ax)

# %%
surrogate_explainer.tree_visualization('pydotplus')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2278x497>

# %%
vis = surrogate_explainer.tree_visualization('dtreeviz', scale=2)
vis

# %% [markdown]
# # Local Explainability Metrics (based on Lime)

# %%
# lime feature importance
lime_explainer = Explainer(based_on='feature_importance',
                      strategy_type='lime',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
lime_explainer.metrics(detailed=True)
# Out:
#                                      Value  Reference
# Metric
# Dataset Stability Gini            0.040501          0
# Dataset Stability Gini [Q0-Q1]    0.035755          0
# Dataset Stability Gini [Q1-Q2]    0.044064          0
# Dataset Stability Gini [Q2-Q3]    0.043679          0
# Dataset Stability Gini [Q3-Q4]    0.037925          0
# Dataset Stability Mean            0.838216          0
# Dataset Stability Mean [Q0-Q1]    0.841385          0
# Dataset Stability Mean [Q1-Q2]    0.832617          0
# Dataset Stability Mean [Q2-Q3]    0.837195          0
# Dataset Stability Mean [Q3-Q4]    0.841558          0
# Dataset Stability Ratio           0.999560          1
# Dataset Stability Ratio [Q0-Q1]   0.999574          1
# Dataset Stability Ratio [Q1-Q2]   0.999292          1
# Dataset Stability Ratio [Q2-Q3]   0.999345          1
# Dataset Stability Ratio [Q3-Q4]   0.999513          1
# Features Stability Gini           0.005818          0
# Features Stability Gini [Q0-Q1]   0.011124          0
# Features Stability Gini [Q1-Q2]   0.009677          0
# Features Stability Gini [Q2-Q3]   0.007831          0
# Features Stability Gini [Q3-Q4]   0.006988          0
# Features Stability Mean           0.939778          0
# Features Stability Mean [Q0-Q1]   0.923791          0
# Features Stability Mean [Q1-Q2]   0.919330          0
# Features Stability Mean [Q2-Q3]   0.921764          0
# Features Stability Mean [Q3-Q4]   0.924503          0
# Features Stability Ratio          0.999976          1
# Features Stability Ratio [Q0-Q1]  0.999892          1
# Features Stability Ratio [Q1-Q2]  0.999933          1
# Features Stability Ratio [Q2-Q3]  0.999959          1
# Features Stability Ratio [Q3-Q4]  0.999956          1

# %%
lime_explainer.bar_plot(max_display=10)

# %%
lime_explainer.show_importance_stability()

# %%
lime_explainer.show_data_stability_boundaries(top_n=10, figsize=(15,10))

# %%
lime_explainer.show_features_stability_boundaries(figsize=(15,10))

# %%
# lime feature importance
shap_explainer = Explainer(based_on='feature_importance',
                      strategy_type='shap',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)
# Out:
# Exact explainer: 442it [00:23, 12.10it/s]

# %%
shap_explainer.metrics(detailed=False)
# Out:
#                              Value  Reference
# Dataset Stability Gini    0.049927          0
# Dataset Stability Mean    0.805318          0
# Dataset Stability Ratio   0.999315          1
# Features Stability Gini   0.012077          0
# Features Stability Mean   0.953876          0
# Features Stability Ratio  0.999895          1

# %%
shap_explainer.metrics(detailed=True)
# Out:
#                                      Value  Reference
# Metric
# Dataset Stability Gini            0.049927          0
# Dataset Stability Gini [Q0-Q1]    0.044546          0
# Dataset Stability Gini [Q1-Q2]    0.041266          0
# Dataset Stability Gini [Q2-Q3]    0.044481          0
# Dataset Stability Gini [Q3-Q4]    0.061469          0
# Dataset Stability Mean            0.805318          0
# Dataset Stability Mean [Q0-Q1]    0.803452          0
# Dataset Stability Mean [Q1-Q2]    0.825168          0
# Dataset Stability Mean [Q2-Q3]    0.820787          0
# Dataset Stability Mean [Q3-Q4]    0.772362          0
# Dataset Stability Ratio           0.999315          1
# Dataset Stability Ratio [Q0-Q1]   0.999253          1
# Dataset Stability Ratio [Q1-Q2]   0.999437          1
# Dataset Stability Ratio [Q2-Q3]   0.999334          1
# Dataset Stability Ratio [Q3-Q4]   0.998688          1
# Features Stability Gini           0.012077          0
# Features Stability Gini [Q0-Q1]   0.015320          0
# Features Stability Gini [Q1-Q2]   0.012661          0
# Features Stability Gini [Q2-Q3]   0.014431          0
# Features Stability Gini [Q3-Q4]   0.025585          0
# Features Stability Mean           0.953876          0
# Features Stability Mean [Q0-Q1]   0.950257          0
# Features Stability Mean [Q1-Q2]   0.947717          0
# Features Stability Mean [Q2-Q3]   0.946625          0
# Features Stability Mean [Q3-Q4]   0.928132          0
# Features Stability Ratio          0.999895          1
# Features Stability Ratio [Q0-Q1]  0.999833          1
# Features Stability Ratio [Q1-Q2]  0.999870          1
# Features Stability Ratio [Q2-Q3]  0.999852          1
# Features Stability Ratio [Q3-Q4]  0.999491          1

# %%
shap_explainer['Features Stability Ratio [Q2-Q3]']
# Out:
# 0.9998518073436206

# %%
shap_explainer['Features Stability Ratio']
# Out:
# 0.9998949189522803

# %%
shap_explainer.show_importance_stability()

# %%
shap_explainer.show_data_stability_boundaries(top_n=10, figsize=(15,10))

# %%
shap_explainer.show_features_stability_boundaries(figsize=(15,10))
