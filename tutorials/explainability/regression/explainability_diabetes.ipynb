# %%
import sys
import os
base_path = os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))
sys.path.insert(0, base_path)

# %% [markdown]
# # Explainability Metrics for Regression

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from holisticai.explainability import Explainer
from holisticai.efficacy.metrics import regression_efficacy_metrics

# %% [markdown]
# ## Data Preprocessing

# %%
dataset = load_diabetes() # load dataset

X = dataset.data # features
y = dataset.target # target 
feature_names = dataset.feature_names # feature names

X = pd.DataFrame(X, columns=feature_names) # convert to dataframe

# %%
X.hist(bins=10, figsize=(10, 10), color = 'mediumslateblue')
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'bp'}>, <Axes: title={'center': 's1'}>,
#         <Axes: title={'center': 's2'}>],
#        [<Axes: title={'center': 's3'}>, <Axes: title={'center': 's4'}>,
#         <Axes: title={'center': 's5'}>],
#        [<Axes: title={'center': 's6'}>, <Axes: >, <Axes: >]], dtype=object)

# %%
from holisticai.bias.plots import correlation_matrix_plot

correlation_matrix_plot(X, target_feature='age', size = (12,7))
# Out:
# <Axes: >

# %% [markdown]
# ## Model Training

# %%
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np
seed = np.random.seed(42) # set seed for reproducibility
# simple preprocessing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed) # train test split


model = GradientBoostingRegressor() # instantiate model
model.fit(X_train, y_train) # fit model

y_pred = model.predict(X_test) # compute predictions

# compute efficacy metrics
regression_efficacy_metrics(y_test, y_pred)
# Out:
#                 Value  Reference
# Metric
# RMSE        53.952020          0
# MAE         44.638564          0
# MAPE         0.399881          0
# Max Error  131.736157          0
# SMAPE        0.164915          0

# %% [markdown]
# # Global Explainability Metrics (based on Permutation Feature Importance)

# %%
# permutation feature importance
permutation_explainer = Explainer(based_on='feature_importance',
                      strategy_type='permutation',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
permutation_explainer.metrics()
# Out:
#                         Value Reference
# Metric
# Explainability Ease  0.750000         1
# Fourth Fifths        0.400000         0
# Position Parity      0.306776         1
# Rank Alignment       0.752946         1
# Region Similarity    0.913947         1
# Spread Divergence    0.460785         -
# Spread Ratio         0.799884         0

# %%
permutation_explainer.partial_dependence_plot()

# %%
permutation_explainer.metrics(detailed=True)
# Out:
#                               Value Reference
# Metric
# Explainability Ease        0.750000         1
# Fourth Fifths              0.400000         0
# Position Parity            0.306776         1
# Position Parity [Q0-Q1]    0.031111         1
# Position Parity [Q1-Q2]    0.485794         1
# Position Parity [Q2-Q3]    0.047897         1
# Position Parity [Q3-Q4]    0.662302         1
# Rank Alignment             0.752946         1
# Rank Alignment [Q0-Q1]     0.704048         1
# Rank Alignment [Q1-Q2]     0.799484         1
# Rank Alignment [Q2-Q3]     0.607817         1
# Rank Alignment [Q3-Q4]     0.900437         1
# Region Similarity          0.913947         1
# Region Similarity [Q0-Q1]  0.916924         1
# Region Similarity [Q1-Q2]  0.898495         1
# Region Similarity [Q2-Q3]  0.931273         1
# Region Similarity [Q3-Q4]  0.909098         1
# Spread Divergence          0.460785         -
# Spread Divergence [Q0-Q1]  0.173728         -
# Spread Divergence [Q1-Q2]  0.166096         -
# Spread Divergence [Q2-Q3]  0.212288         -
# Spread Divergence [Q3-Q4]  0.199594         -
# Spread Ratio               0.799884         0
# Spread Ratio [Q0-Q1]       0.924551         0
# Spread Ratio [Q1-Q2]       0.927866         0
# Spread Ratio [Q2-Q3]       0.907805         0
# Spread Ratio [Q3-Q4]       0.913317         0

# %%
# Contrast Whole Importance vs. Group Importance
# -> Order -> mean positions
# -> Range -> match range of position 
# -> Similarity -> compute similarity
# -> e.g. we can see that Q0-Q1 and Q2-Q3 strong changes in their position but their importance weights maintains a high similarity with the whole model.
# -> e.g. we can see that Q1-Q2 and Q3-Q4 small changes in their position and their importance weights maintains a high similarity with the whole model.
permutation_explainer.contrast_visualization(show_connections=False)
# TODO separate show connections sin a second matrix

# %%
permutation_explainer.bar_plot(max_display=10)

# %%
permutation_explainer.feature_importance_table(sorted_by='Global', top_n=5)
# Out:
# <style type="text/css">
# #T_56df1_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
# }
# #T_56df1_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 38.0%, transparent 38.0%);
# }
# #T_56df1_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 64.7%, transparent 64.7%);
# }
# #T_56df1_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 28.1%, transparent 28.1%);
# }
# #T_56df1_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 87.0%, transparent 87.0%);
# }
# #T_56df1_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 94.1%, transparent 94.1%);
# }
# #T_56df1_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 74.3%, transparent 74.3%);
# }
# #T_56df1_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 51.2%, transparent 51.2%);
# }
# #T_56df1_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 71.6%, transparent 71.6%);
# }
# #T_56df1_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 40.5%, transparent 40.5%);
# }
# #T_56df1_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 29.8%, transparent 29.8%);
# }
# #T_56df1_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.5%, transparent 22.5%);
# }
# #T_56df1_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 17.5%, transparent 17.5%);
# }
# #T_56df1_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 23.6%, transparent 23.6%);
# }
# #T_56df1_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 39.6%, transparent 39.6%);
# }
# #T_56df1_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 16.9%, transparent 16.9%);
# }
# #T_56df1_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 47.8%, transparent 47.8%);
# }
# #T_56df1_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 42.2%, transparent 42.2%);
# }
# #T_56df1_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 57.5%, transparent 57.5%);
# }
# #T_56df1_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 27.6%, transparent 27.6%);
# }
# #T_56df1_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 14.9%, transparent 14.9%);
# }
# #T_56df1_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 22.9%, transparent 22.9%);
# }
# #T_56df1_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 18.0%, transparent 18.0%);
# }
# #T_56df1_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 13.0%, transparent 13.0%);
# }
# #T_56df1_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 26.4%, transparent 26.4%);
# }
# </style>
# <table id="T_56df1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56df1_level0_col0" class="col_heading level0 col0" >Global Importance</th>
#       <th id="T_56df1_level0_col1" class="col_heading level0 col1" >[Q0-Q1] Importance</th>
#       <th id="T_56df1_level0_col2" class="col_heading level0 col2" >[Q1-Q2] Importance</th>
#       <th id="T_56df1_level0_col3" class="col_heading level0 col3" >[Q2-Q3] Importance</th>
#       <th id="T_56df1_level0_col4" class="col_heading level0 col4" >[Q3-Q4] Importance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56df1_level0_row0" class="row_heading level0 row0" >bmi</th>
#       <td id="T_56df1_row0_col0" class="data row0 col0" >0.321886</td>
#       <td id="T_56df1_row0_col1" class="data row0 col1" >0.122267</td>
#       <td id="T_56df1_row0_col2" class="data row0 col2" >0.208239</td>
#       <td id="T_56df1_row0_col3" class="data row0 col3" >0.090481</td>
#       <td id="T_56df1_row0_col4" class="data row0 col4" >0.280007</td>
#     </tr>
#     <tr>
#       <th id="T_56df1_level0_row1" class="row_heading level0 row1" >s5</th>
#       <td id="T_56df1_row1_col0" class="data row1 col0" >0.302777</td>
#       <td id="T_56df1_row1_col1" class="data row1 col1" >0.239292</td>
#       <td id="T_56df1_row1_col2" class="data row1 col2" >0.164905</td>
#       <td id="T_56df1_row1_col3" class="data row1 col3" >0.230507</td>
#       <td id="T_56df1_row1_col4" class="data row1 col4" >0.130517</td>
#     </tr>
#     <tr>
#       <th id="T_56df1_level0_row2" class="row_heading level0 row2" >bp</th>
#       <td id="T_56df1_row2_col0" class="data row2 col0" >0.095825</td>
#       <td id="T_56df1_row2_col1" class="data row2 col1" >0.072358</td>
#       <td id="T_56df1_row2_col2" class="data row2 col2" >0.056336</td>
#       <td id="T_56df1_row2_col3" class="data row2 col3" >0.075909</td>
#       <td id="T_56df1_row2_col4" class="data row2 col4" >0.127500</td>
#     </tr>
#     <tr>
#       <th id="T_56df1_level0_row3" class="row_heading level0 row3" >age</th>
#       <td id="T_56df1_row3_col0" class="data row3 col0" >0.054271</td>
#       <td id="T_56df1_row3_col1" class="data row3 col1" >0.153966</td>
#       <td id="T_56df1_row3_col2" class="data row3 col2" >0.135719</td>
#       <td id="T_56df1_row3_col3" class="data row3 col3" >0.185101</td>
#       <td id="T_56df1_row3_col4" class="data row3 col4" >0.088731</td>
#     </tr>
#     <tr>
#       <th id="T_56df1_level0_row4" class="row_heading level0 row4" >s6</th>
#       <td id="T_56df1_row4_col0" class="data row4 col0" >0.047958</td>
#       <td id="T_56df1_row4_col1" class="data row4 col1" >0.073860</td>
#       <td id="T_56df1_row4_col2" class="data row4 col2" >0.058013</td>
#       <td id="T_56df1_row4_col3" class="data row4 col3" >0.041822</td>
#       <td id="T_56df1_row4_col4" class="data row4 col4" >0.085115</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Global Explainability metrics (based on Surrogate Model)

# %%
# surrogate feature importance
surrogate_explainer = Explainer(based_on='feature_importance',
                      strategy_type='surrogate',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
surrogate_explainer.metrics()
# Out:
#                         Value Reference
# Metric
# Explainability Ease  0.800000         1
# Fourth Fifths        0.100000         0
# Spread Divergence    1.533691         -
# Spread Ratio         0.333927         0
# Surrogacy Efficacy   0.083324         0

# %%
_,ax=plt.subplots(figsize=(15,5))
surrogate_explainer.partial_dependence_plot(ax=ax, kind="both") # kind: [individual,average,both]

# %%
surrogate_explainer.bar_plot(max_display=5)

# %%
surrogate_explainer.feature_importance_table(sorted_by='Global', top_n=10)
# Out:
# <style type="text/css">
# #T_15d3e_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 100.0%, transparent 100.0%);
# }
# #T_15d3e_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 40.8%, transparent 40.8%);
# }
# #T_15d3e_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 3.3%, transparent 3.3%);
# }
# #T_15d3e_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, lightgreen 2.4%, transparent 2.4%);
# }
# #T_15d3e_row4_col0, #T_15d3e_row5_col0, #T_15d3e_row6_col0, #T_15d3e_row7_col0, #T_15d3e_row8_col0, #T_15d3e_row9_col0 {
#   width: 10em;
# }
# </style>
# <table id="T_15d3e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15d3e_level0_col0" class="col_heading level0 col0" >Global Importance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Variable</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15d3e_level0_row0" class="row_heading level0 row0" >bmi</th>
#       <td id="T_15d3e_row0_col0" class="data row0 col0" >0.682537</td>
#     </tr>
#     <tr>
#       <th id="T_15d3e_level0_row1" class="row_heading level0 row1" >s5</th>
#       <td id="T_15d3e_row1_col0" class="data row1 col0" >0.278768</td>
#     </tr>
#     <tr>
#       <th id="T_15d3e_level0_row2" class="row_heading level0 row2" >s4</th>
#       <td id="T_15d3e_row2_col0" class="data row2 col0" >0.022591</td>
#     </tr>
#     <tr>
#       <th id="T_15d3e_level0_row3" class="row_heading level0 row3" >s2</th>
#       <td id="T_15d3e_row3_col0" class="data row3 col0" >0.016105</td>
#     </tr>
#     <tr>
#       <th id="T_15d3e_level0_row4" class="row_heading level0 row4" >age</th>
#       <td id="T_15d3e_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15d3e_level0_row5" class="row_heading level0 row5" >sex</th>
#       <td id="T_15d3e_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15d3e_level0_row6" class="row_heading level0 row6" >bp</th>
#       <td id="T_15d3e_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15d3e_level0_row7" class="row_heading level0 row7" >s1</th>
#       <td id="T_15d3e_row7_col0" class="data row7 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15d3e_level0_row8" class="row_heading level0 row8" >s3</th>
#       <td id="T_15d3e_row8_col0" class="data row8 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_15d3e_level0_row9" class="row_heading level0 row9" >s6</th>
#       <td id="T_15d3e_row9_col0" class="data row9 col0" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
_,ax = plt.subplots(figsize=(15,3))
_ = surrogate_explainer.tree_visualization('sklearn', ax=ax)

# %%
surrogate_explainer.tree_visualization('pydotplus')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2109x497>

# %%
vis = surrogate_explainer.tree_visualization('dtreeviz', scale=2)
vis

# %% [markdown]
# # Local Explainability Metrics (based on Lime)

# %%
# lime feature importance
lime_explainer = Explainer(based_on='feature_importance',
                      strategy_type='lime',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
lime_explainer.metrics()
# Out:
#                       Value  Referemce
# Metric
# Data Stability     0.039738          0
# Feature Stability  0.005892          0

# %%
lime_explainer.metrics(detailed=True)
# Out:
#                               Value  Referemce
# Metric
# Data Stability             0.039738          0
# Data Stability [Q0-Q1]     0.039918          0
# Data Stability [Q1-Q2]     0.036690          0
# Data Stability [Q2-Q3]     0.039330          0
# Data Stability [Q3-Q4]     0.041357          0
# Feature Stability          0.005892          0
# Feature Stability [Q0-Q1]  0.011934          0
# Feature Stability [Q1-Q2]  0.007988          0
# Feature Stability [Q2-Q3]  0.008936          0
# Feature Stability [Q3-Q4]  0.007636          0

# %%
lime_explainer.bar_plot(max_display=10)

# %%
lime_explainer.show_importance_stability()

# %%
lime_explainer.show_data_stability_boundaries(top_n=10, figsize=(15,6))

# %%
lime_explainer.show_features_stability_boundaries(n_cols=4, n_rows=2, figsize=(15,6))

# %% [markdown]
# # Local Explainability Metrics (based on Shap)

# %%
# lime feature importance
shap_explainer = Explainer(based_on='feature_importance',
                      strategy_type='shap',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)
# Out:
# Exact explainer: 442it [00:28, 10.81it/s]

# %%
shap_explainer.metrics(detailed=False)
# Out:
#                       Value  Referemce
# Metric
# Data Stability     0.049974          0
# Feature Stability  0.012074          0

# %%
shap_explainer.metrics(detailed=True)
# Out:
#                               Value  Referemce
# Metric
# Data Stability             0.049974          0
# Data Stability [Q0-Q1]     0.044779          0
# Data Stability [Q1-Q2]     0.041266          0
# Data Stability [Q2-Q3]     0.044481          0
# Data Stability [Q3-Q4]     0.061469          0
# Feature Stability          0.012074          0
# Feature Stability [Q0-Q1]  0.015354          0
# Feature Stability [Q1-Q2]  0.012661          0
# Feature Stability [Q2-Q3]  0.014431          0
# Feature Stability [Q3-Q4]  0.025585          0

# %%
shap_explainer['Feature Stability [Q2-Q3]']
# Out:
# 0.014431057067474

# %%
shap_explainer['Feature Stability']
# Out:
# 0.012073773244120626

# %%
shap_explainer.show_importance_stability()

# %%
shap_explainer.show_data_stability_boundaries(top_n=10, figsize=(15,6))

# %%
shap_explainer.show_features_stability_boundaries(n_cols=4, n_rows=2, figsize=(15,6))
