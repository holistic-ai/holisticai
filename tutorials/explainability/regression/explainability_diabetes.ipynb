# %%
import sys
sys.path.insert(0, '../../')

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pandas as pd

from holisticai.explainability import Explainer
from holisticai.metrics.efficacy import regression_efficacy_metrics

# %%
dataset = load_diabetes() # load dataset

X = dataset.data # features
y = dataset.target # target 
feature_names = dataset.feature_names # feature names

X = pd.DataFrame(X, columns=feature_names) # convert to dataframe

# %%
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np
seed = np.random.seed(42) # set seed for reproducibility
# simple preprocessing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed) # train test split

model = GradientBoostingRegressor() # instantiate model
model.fit(X_train, y_train) # fit model

y_pred = model.predict(X_test) # compute predictions

# compute efficacy metrics
regression_efficacy_metrics(y_test, y_pred)
# Out:
#                 Value  Reference
# Metric
# RMSE        53.952020          0
# MAE         44.638564          0
# MAPE         0.399881          0
# Max Error  131.736157          0
# SMAPE        0.164915          0

# %% [markdown]
# # Global Explainability Metrics (based on Permutation Feature Importance)

# %%
# permutation feature importance
permutation_explainer = Explainer(based_on='feature_importance',
                      strategy_type='permutation',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
permutation_explainer.metrics()
# Out:
#                         Value Reference
# Metric
# Explainability Ease  0.750000         1
# Fourth Fifths        0.400000         0
# Position Parity      0.306776         1
# Rank Alignment       0.752946         1
# Spread Divergence    0.460785         -
# Spread Ratio         0.799884         0

# %%
permutation_explainer.partial_dependence_plot(kind='both')
# Out:
# The accumulated feature importance for 4 features is equal 0.7748 < 0.8.

# %%
permutation_explainer.bar_plot(max_display=10)

# %%
permutation_explainer.feature_importance_table(sorted_by='Global', top_n=5)
# Out:
# <style type="text/css">
# #T_3929a_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 100.0%, transparent 100.0%);
# }
# #T_3929a_row0_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 38.0%, transparent 38.0%);
# }
# #T_3929a_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 64.7%, transparent 64.7%);
# }
# #T_3929a_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 28.1%, transparent 28.1%);
# }
# #T_3929a_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 87.0%, transparent 87.0%);
# }
# #T_3929a_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 94.1%, transparent 94.1%);
# }
# #T_3929a_row1_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 74.3%, transparent 74.3%);
# }
# #T_3929a_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 51.2%, transparent 51.2%);
# }
# #T_3929a_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 71.6%, transparent 71.6%);
# }
# #T_3929a_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 40.5%, transparent 40.5%);
# }
# #T_3929a_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 29.8%, transparent 29.8%);
# }
# #T_3929a_row2_col1, #T_3929a_row2_col2, #T_3929a_row2_col3, #T_3929a_row4_col0, #T_3929a_row4_col2, #T_3929a_row4_col4 {
#   width: 10em;
# }
# #T_3929a_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 39.6%, transparent 39.6%);
# }
# #T_3929a_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 16.9%, transparent 16.9%);
# }
# #T_3929a_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 47.8%, transparent 47.8%);
# }
# #T_3929a_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 42.2%, transparent 42.2%);
# }
# #T_3929a_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 57.5%, transparent 57.5%);
# }
# #T_3929a_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 27.6%, transparent 27.6%);
# }
# #T_3929a_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 31.9%, transparent 31.9%);
# }
# #T_3929a_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 35.9%, transparent 35.9%);
# }
# </style>
# <table id="T_3929a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3929a_level0_col0" class="col_heading level0 col0" >Global Importance</th>
#       <th id="T_3929a_level0_col1" class="col_heading level0 col1" >[Q0-Q1] Importance</th>
#       <th id="T_3929a_level0_col2" class="col_heading level0 col2" >[Q1-Q2] Importance</th>
#       <th id="T_3929a_level0_col3" class="col_heading level0 col3" >[Q2-Q3] Importance</th>
#       <th id="T_3929a_level0_col4" class="col_heading level0 col4" >[Q3-Q4] Importance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3929a_level0_row0" class="row_heading level0 row0" >bmi</th>
#       <td id="T_3929a_row0_col0" class="data row0 col0" >0.321886</td>
#       <td id="T_3929a_row0_col1" class="data row0 col1" >0.122267</td>
#       <td id="T_3929a_row0_col2" class="data row0 col2" >0.208239</td>
#       <td id="T_3929a_row0_col3" class="data row0 col3" >0.090481</td>
#       <td id="T_3929a_row0_col4" class="data row0 col4" >0.280007</td>
#     </tr>
#     <tr>
#       <th id="T_3929a_level0_row1" class="row_heading level0 row1" >s5</th>
#       <td id="T_3929a_row1_col0" class="data row1 col0" >0.302777</td>
#       <td id="T_3929a_row1_col1" class="data row1 col1" >0.239292</td>
#       <td id="T_3929a_row1_col2" class="data row1 col2" >0.164905</td>
#       <td id="T_3929a_row1_col3" class="data row1 col3" >0.230507</td>
#       <td id="T_3929a_row1_col4" class="data row1 col4" >0.130517</td>
#     </tr>
#     <tr>
#       <th id="T_3929a_level0_row2" class="row_heading level0 row2" >bp</th>
#       <td id="T_3929a_row2_col0" class="data row2 col0" >0.095825</td>
#       <td id="T_3929a_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_3929a_row2_col2" class="data row2 col2" >nan</td>
#       <td id="T_3929a_row2_col3" class="data row2 col3" >nan</td>
#       <td id="T_3929a_row2_col4" class="data row2 col4" >0.127500</td>
#     </tr>
#     <tr>
#       <th id="T_3929a_level0_row3" class="row_heading level0 row3" >age</th>
#       <td id="T_3929a_row3_col0" class="data row3 col0" >0.054271</td>
#       <td id="T_3929a_row3_col1" class="data row3 col1" >0.153966</td>
#       <td id="T_3929a_row3_col2" class="data row3 col2" >0.135719</td>
#       <td id="T_3929a_row3_col3" class="data row3 col3" >0.185101</td>
#       <td id="T_3929a_row3_col4" class="data row3 col4" >0.088731</td>
#     </tr>
#     <tr>
#       <th id="T_3929a_level0_row4" class="row_heading level0 row4" >sex</th>
#       <td id="T_3929a_row4_col0" class="data row4 col0" >nan</td>
#       <td id="T_3929a_row4_col1" class="data row4 col1" >0.102726</td>
#       <td id="T_3929a_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_3929a_row4_col3" class="data row4 col3" >0.115401</td>
#       <td id="T_3929a_row4_col4" class="data row4 col4" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Global Explainability metrics (based on Surrogate Model)

# %%
# surrogate feature importance
surrogate_explainer = Explainer(based_on='feature_importance',
                      strategy_type='surrogate',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
surrogate_explainer.metrics()
# Out:
#                         Value Reference
# Metric
# Explainability Ease  0.900000         1
# Fourth Fifths        0.100000         0
# Spread Divergence    1.533691         -
# Spread Ratio         0.333927         0
# Surrogacy Efficacy   0.083324         0

# %%
surrogate_explainer.partial_dependence_plot(kind="both")
# Out:
# The accumulated feature importance for 1 features is equal 0.6825 < 0.8.

# %%
surrogate_explainer.bar_plot(max_display=5)

# %%
surrogate_explainer.feature_importance_table(sorted_by='Global', top_n=10)
# Out:
# <style type="text/css">
# #T_7c26b_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_7c26b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c26b_level0_col0" class="col_heading level0 col0" >Global Importance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Variable</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c26b_level0_row0" class="row_heading level0 row0" >bmi</th>
#       <td id="T_7c26b_row0_col0" class="data row0 col0" >0.682537</td>
#     </tr>
#   </tbody>
# </table>

# %%
_,ax = plt.subplots(figsize=(15,3))
_ = surrogate_explainer.tree_visualization('sklearn', ax=ax)

# %%
surrogate_explainer.tree_visualization('pydotplus')
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=2278x497>

# %%
vis = surrogate_explainer.tree_visualization('dtreeviz', scale=2)
vis

# %% [markdown]
# # Local Explainability Metrics (based on Lime)

# %%
# lime feature importance
lime_explainer = Explainer(based_on='feature_importance',
                      strategy_type='lime',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
lime_explainer.metrics()
# Out:
#                       Value  Reference
# Metric
# Data Stability     0.039340          0
# Feature Stability  0.005578          0

# %%
lime_explainer.show_importance_stability()

# %%
lime_explainer.show_data_stability_boundaries(top_n=10, figsize=(15,6))

# %%
lime_explainer.show_features_stability_boundaries(figsize=(15,6))

# %%
# lime feature importance
shap_explainer = Explainer(based_on='feature_importance',
                      strategy_type='shap',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)
# Out:
# Exact explainer: 442it [01:46,  3.92it/s]

# %%
shap_explainer.metrics()
# Out:
#                       Value  Reference
# Metric
# Data Stability     0.049946          0
# Feature Stability  0.012055          0

# %%
shap_explainer.metrics(detailed=True)
# Out:
#                               Value  Reference
# Metric
# Data Stability             0.049946          0
# Data Stability [Q0-Q1]     0.044680          0
# Data Stability [Q1-Q2]     0.041266          0
# Data Stability [Q2-Q3]     0.044481          0
# Data Stability [Q3-Q4]     0.061469          0
# Feature Stability          0.012055          0
# Feature Stability [Q0-Q1]  0.015243          0
# Feature Stability [Q1-Q2]  0.012661          0
# Feature Stability [Q2-Q3]  0.014431          0
# Feature Stability [Q3-Q4]  0.025585          0

# %%
shap_explainer.show_importance_stability()

# %%
shap_explainer.show_data_stability_boundaries(top_n=10, figsize=(15,6))

# %%
shap_explainer.show_features_stability_boundaries(figsize=(15,6))
