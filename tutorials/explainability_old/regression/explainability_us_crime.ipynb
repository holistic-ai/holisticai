# %% [markdown]
# # Explainability Metrics for Regression

# %%
import sys, os
base_path = os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))
sys.path.insert(0, base_path)

# %%
from holisticai.datasets import load_us_crime
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

from holisticai.explainability import Explainer
from holisticai.metrics.efficacy import regression_efficacy_metrics

# %% [markdown]
# ## Data Preprocessing

# %%
dataset = load_us_crime(return_X_y=False, as_frame=True)
df = pd.concat([dataset["data"], dataset["target"]], axis=1)
df.head()
# Out:
#    state  county  community        communityname  fold  population  \
# 0    8.0     NaN        NaN         Lakewoodcity   1.0        0.19
# 1   53.0     NaN        NaN          Tukwilacity   1.0        0.00
# 2   24.0     NaN        NaN         Aberdeentown   1.0        0.00
# 3   34.0     5.0    81440.0  Willingborotownship   1.0        0.04
# 4   42.0    95.0     6096.0    Bethlehemtownship   1.0        0.01
#
#    householdsize  racepctblack  racePctWhite  racePctAsian  ...  LandArea  \
# 0           0.33          0.02          0.90          0.12  ...      0.12
# 1           0.16          0.12          0.74          0.45  ...      0.02
# 2           0.42          0.49          0.56          0.17  ...      0.01
# 3           0.77          1.00          0.08          0.12  ...      0.02
# 4           0.55          0.02          0.95          0.09  ...      0.04
#
#    PopDens  PctUsePubTrans  PolicCars  PolicOperBudg  LemasPctPolicOnPatr  \
# 0     0.26            0.20       0.06           0.04                  0.9
# 1     0.12            0.45        NaN            NaN                  NaN
# 2     0.21            0.02        NaN            NaN                  NaN
# 3     0.39            0.28        NaN            NaN                  NaN
# 4     0.09            0.02        NaN            NaN                  NaN
#
#    LemasGangUnitDeploy  LemasPctOfficDrugUn  PolicBudgPerPop  \
# 0                  0.5                 0.32             0.14
# 1                  NaN                 0.00              NaN
# 2                  NaN                 0.00              NaN
# 3                  NaN                 0.00              NaN
# 4                  NaN                 0.00              NaN
#
#    ViolentCrimesPerPop
# 0                 0.20
# 1                 0.67
# 2                 0.43
# 3                 0.12
# 4                 0.03
#
# [5 rows x 128 columns]

# %%
def preprocess_us_crime_dataset(df, protected_feature):
  """Performs the pre-processing step of the data."""
  # Remove NaN elements from dataframe
  df_ = df.copy()
  df_clean = df_.iloc[:,[i for i,n in enumerate(df_.isna().sum(axis=0).T.values) if n<1000]]
  df_clean = df_clean.dropna()
  # Get the protected attribute vectors
  group_a = df_clean[protected_feature].apply(lambda x: x>0.5)
  group_b =  1-group_a
  group_b = group_b.astype('bool')
  # Remove unnecessary columns
  cols = [c for c in df_clean.columns if (not c.startswith('race')) and (not c.startswith('age'))]
  df_clean = df_clean[cols].iloc[:,3:]
  return df_clean, group_a, group_b

# %%
df_clean, group_a, group_b = preprocess_us_crime_dataset(df, 'racePctWhite')
X = df_clean.iloc[:,:-1]
y = df_clean.iloc[:,-1]

# %% [markdown]
# ## Model Training

# %%
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np
seed = np.random.seed(42) # set seed for reproducibility
# simple preprocessing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed) # train test split


model = GradientBoostingRegressor() # instantiate model
#model = LinearRegression()
model.fit(X_train, y_train) # fit model

y_pred = model.predict(X_test) # compute predictions

# compute efficacy metrics
regression_efficacy_metrics(y_test, y_pred)
# Out:
#                   Value  Reference
# Metric
# RMSE       1.396764e-01          0
# MAE        9.038879e-02          0
# MAPE       1.185104e+12          0
# Max Error  7.651164e-01          0
# SMAPE      2.367336e-01          0

# %% [markdown]
# # Global Explainability Metrics (based on Permutation Feature Importance)

# %%
# permutation feature importance
permutation_explainer = Explainer(based_on='feature_importance',
                      strategy_type='permutation',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
permutation_explainer.metrics()
# Out:
#                         Value Reference
# Metric
# Explainability Ease  0.679348         1
# Fourth Fifths        0.206522         0
# Position Parity      0.061425         1
# Rank Alignment       0.759758         1
# Spread Divergence    1.321530         -
# Spread Ratio         0.707742         0

# %%
permutation_explainer.bar_plot(max_display=10)

# %%
_, ax = plt.subplots(figsize=(12, 8))
permutation_explainer.partial_dependence_plot(last=10, alpha=0.7, ax = ax)
# Out:
# The accumulated feature importance for 11 features is equal 0.6847 < 0.7.

# %% [markdown]
# Conditional Feature Importance Metrics

# %%
# How change the feature importance for each quantil with respect to the feature importance of the whole model?
permutation_explainer.contrast_visualization(show_connections=False)

# %%
permutation_explainer.feature_importance_table(sorted_by='Global', top_n=5)
# Out:
# <style type="text/css">
# #T_4e5fc_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 100.0%, transparent 100.0%);
# }
# #T_4e5fc_row0_col1, #T_4e5fc_row1_col1, #T_4e5fc_row4_col2 {
#   width: 10em;
# }
# #T_4e5fc_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 29.8%, transparent 29.8%);
# }
# #T_4e5fc_row0_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 56.2%, transparent 56.2%);
# }
# #T_4e5fc_row0_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 52.1%, transparent 52.1%);
# }
# #T_4e5fc_row1_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 75.5%, transparent 75.5%);
# }
# #T_4e5fc_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 28.2%, transparent 28.2%);
# }
# #T_4e5fc_row1_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 41.4%, transparent 41.4%);
# }
# #T_4e5fc_row1_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 34.0%, transparent 34.0%);
# }
# #T_4e5fc_row2_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 32.8%, transparent 32.8%);
# }
# #T_4e5fc_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 39.5%, transparent 39.5%);
# }
# #T_4e5fc_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 22.4%, transparent 22.4%);
# }
# #T_4e5fc_row2_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 12.0%, transparent 12.0%);
# }
# #T_4e5fc_row2_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 4.4%, transparent 4.4%);
# }
# #T_4e5fc_row3_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 20.8%, transparent 20.8%);
# }
# #T_4e5fc_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 7.0%, transparent 7.0%);
# }
# #T_4e5fc_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 6.2%, transparent 6.2%);
# }
# #T_4e5fc_row3_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 5.4%, transparent 5.4%);
# }
# #T_4e5fc_row3_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 5.3%, transparent 5.3%);
# }
# #T_4e5fc_row4_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 19.4%, transparent 19.4%);
# }
# #T_4e5fc_row4_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 17.5%, transparent 17.5%);
# }
# #T_4e5fc_row4_col3 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 13.5%, transparent 13.5%);
# }
# #T_4e5fc_row4_col4 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 44.2%, transparent 44.2%);
# }
# </style>
# <table id="T_4e5fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e5fc_level0_col0" class="col_heading level0 col0" >Global Importance</th>
#       <th id="T_4e5fc_level0_col1" class="col_heading level0 col1" >[Q0-Q1] Importance</th>
#       <th id="T_4e5fc_level0_col2" class="col_heading level0 col2" >[Q1-Q2] Importance</th>
#       <th id="T_4e5fc_level0_col3" class="col_heading level0 col3" >[Q2-Q3] Importance</th>
#       <th id="T_4e5fc_level0_col4" class="col_heading level0 col4" >[Q3-Q4] Importance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Variable</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e5fc_level0_row0" class="row_heading level0 row0" >PctIlleg</th>
#       <td id="T_4e5fc_row0_col0" class="data row0 col0" >0.224214</td>
#       <td id="T_4e5fc_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_4e5fc_row0_col2" class="data row0 col2" >0.066781</td>
#       <td id="T_4e5fc_row0_col3" class="data row0 col3" >0.126036</td>
#       <td id="T_4e5fc_row0_col4" class="data row0 col4" >0.116799</td>
#     </tr>
#     <tr>
#       <th id="T_4e5fc_level0_row1" class="row_heading level0 row1" >PctKids2Par</th>
#       <td id="T_4e5fc_row1_col0" class="data row1 col0" >0.169332</td>
#       <td id="T_4e5fc_row1_col1" class="data row1 col1" >nan</td>
#       <td id="T_4e5fc_row1_col2" class="data row1 col2" >0.063301</td>
#       <td id="T_4e5fc_row1_col3" class="data row1 col3" >0.092722</td>
#       <td id="T_4e5fc_row1_col4" class="data row1 col4" >0.076164</td>
#     </tr>
#     <tr>
#       <th id="T_4e5fc_level0_row2" class="row_heading level0 row2" >pctWInvInc</th>
#       <td id="T_4e5fc_row2_col0" class="data row2 col0" >0.073604</td>
#       <td id="T_4e5fc_row2_col1" class="data row2 col1" >0.088453</td>
#       <td id="T_4e5fc_row2_col2" class="data row2 col2" >0.050305</td>
#       <td id="T_4e5fc_row2_col3" class="data row2 col3" >0.026890</td>
#       <td id="T_4e5fc_row2_col4" class="data row2 col4" >0.009787</td>
#     </tr>
#     <tr>
#       <th id="T_4e5fc_level0_row3" class="row_heading level0 row3" >PctPersDenseHous</th>
#       <td id="T_4e5fc_row3_col0" class="data row3 col0" >0.046580</td>
#       <td id="T_4e5fc_row3_col1" class="data row3 col1" >0.015796</td>
#       <td id="T_4e5fc_row3_col2" class="data row3 col2" >0.014007</td>
#       <td id="T_4e5fc_row3_col3" class="data row3 col3" >0.012161</td>
#       <td id="T_4e5fc_row3_col4" class="data row3 col4" >0.011817</td>
#     </tr>
#     <tr>
#       <th id="T_4e5fc_level0_row4" class="row_heading level0 row4" >PctFam2Par</th>
#       <td id="T_4e5fc_row4_col0" class="data row4 col0" >0.043439</td>
#       <td id="T_4e5fc_row4_col1" class="data row4 col1" >0.039200</td>
#       <td id="T_4e5fc_row4_col2" class="data row4 col2" >nan</td>
#       <td id="T_4e5fc_row4_col3" class="data row4 col3" >0.030350</td>
#       <td id="T_4e5fc_row4_col4" class="data row4 col4" >0.099208</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Global Explainability metrics (based on Surrogate Model)

# %%
# surrogate feature importance
surrogate_explainer = Explainer(based_on='feature_importance',
                      strategy_type='surrogate',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
surrogate_explainer.metrics()
# Out:
#                         Value Reference
# Metric
# Explainability Ease  1.000000         1
# Fourth Fifths        0.010870         0
# Spread Divergence    3.463653         -
# Spread Ratio         0.234008         0
# Surrogacy Efficacy   0.129917         0

# %%
surrogate_explainer.bar_plot(max_display=6)

# %%
_, ax = plt.subplots(figsize=(5, 5))
surrogate_explainer.partial_dependence_plot(last=1, ax=ax, kind='both')
# Out:
# The accumulated feature importance for 1 features is equal 0.6978 < 0.8.

# %%
surrogate_explainer.feature_importance_table(sorted_by='Global', top_n=10)
# Out:
# <style type="text/css">
# #T_cd420_row0_col0 {
#   width: 10em;
#   background: linear-gradient(90deg, darkgreen 100.0%, transparent 100.0%);
# }
# </style>
# <table id="T_cd420">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd420_level0_col0" class="col_heading level0 col0" >Global Importance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Variable</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd420_level0_row0" class="row_heading level0 row0" >PctIlleg</th>
#       <td id="T_cd420_row0_col0" class="data row0 col0" >0.697821</td>
#     </tr>
#   </tbody>
# </table>

# %%
_,ax = plt.subplots(figsize=(15,3))
_ = surrogate_explainer.tree_visualization('sklearn', fontsize=7, ax=ax)

# %%
vis = surrogate_explainer.tree_visualization('dtreeviz', scale=2)
vis

# %% [markdown]
# # Local Explainability Metrics (based on Lime)

# %%
# lime feature importance
lime_explainer = Explainer(based_on='feature_importance',
                      strategy_type='lime',
                      model_type='regression',
                      model = model, 
                      x = X, 
                      y = y)

# %%
lime_explainer.metrics()
# Out:
#                       Value  Reference
# Metric
# Data Stability     0.010347          0
# Feature Stability  0.002078          0

# %%
lime_explainer.metrics(detailed=True)
# Out:
#                               Value  Reference
# Metric
# Data Stability             0.010347          0
# Data Stability [Q0-Q1]     0.005697          0
# Data Stability [Q1-Q2]     0.006151          0
# Data Stability [Q2-Q3]     0.008655          0
# Data Stability [Q3-Q4]     0.012915          0
# Feature Stability          0.002078          0
# Feature Stability [Q0-Q1]  0.003011          0
# Feature Stability [Q1-Q2]  0.003278          0
# Feature Stability [Q2-Q3]  0.003910          0
# Feature Stability [Q3-Q4]  0.006361          0

# %%
lime_explainer.show_importance_stability()

# %%
lime_explainer.show_data_stability_boundaries(top_n=10, figsize=(15,5))

# %%
lime_explainer.show_features_stability_boundaries(figsize=(15,5))
